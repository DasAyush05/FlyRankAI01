# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/DasAyush05/FlyRankAI01/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !git clone https://github.com/DasAyush05/FlyRankAI01.git
# Out:
# fatal: destination path 'FlyRankAI01' already exists and is not an empty directory.

# %%
# !ls FlyRankAI01
# Out:
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     SETUP.md	 work
# CLAUDE.md  docs		notebooks  requirements.txt  skills
# data	   GUIDE.md	outputs    scripts	     submission

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I choose the SEO Content Performance Prediction lane because it focuses on identifying which web pages are likely to improve or decline in search performance. This can help content teams decide which pages should be updated first. I chose this lane because it uses the starter dataset and is practical for solving a real business problem.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Decision: Decide which web pages should be updated first to improve SEO performance.
#
# Action: Recommend the pages that are most likely to lose traffic so the content team can update them before rankings drop.
#
# Cost of a wrong recommendation: If the wrong pages are selected, the team may waste time updating pages that do not need attention while important pages continue to lose traffic and rankings.
#
# Why ML can help: Machine learning can analyze historical SEO data and identify patterns that are difficult to detect manually, helping prioritize pages more effectively.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The starter dataset contains 30,000 web pages, providing enough data to identify meaningful SEO patterns. The average CTR is 0.5107, showing that user engagement varies across pages. The average search position is 16.34, which indicates that many pages are not yet ranked on the first page of search results. These numbers suggest that predicting which pages should be updated first can help improve SEO performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("FlyRankAI01/data/raw/content_refresh_anonymized.csv")

print("Number of pages:", len(df))
print("Average CTR:", round(df["ctr"].mean(), 4))
print("Average Position:", round(df["avg_position"].mean(), 2))
# Out:
# Number of pages: 30000
# Average CTR: 0.5107
# Average Position: 16.34

# %%
import os

for root, dirs, files in os.walk("FlyRankAI01/data"):
    for file in files:
        print(os.path.join(root, file))
# Out:
# FlyRankAI01/data/raw/content_refresh_anonymized.csv

# %%
# !pwd
# Out:
# /content

# %%
# !ls -R
# Out:
# .:
# FlyRankAI01  sample_data
#
# ./FlyRankAI01:
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     SETUP.md	 work
# CLAUDE.md  docs		notebooks  requirements.txt  skills
# data	   GUIDE.md	outputs    scripts	     submission
#
# ./FlyRankAI01/data:
# raw
#
# ./FlyRankAI01/data/raw:
# content_refresh_anonymized.csv
#
# ./FlyRankAI01/docs:
# data-dictionary.md		     ml-core-foundation-framework.md
# flyrank-seo-research-march-2026.pdf  ml-intern-dataset-and-lane-guide.md
# intern-free-tooling-guide.md
#
# ./FlyRankAI01/notebooks:
# 01_first_look_and_discovery.ipynb   03_working_with_the_full_release.ipynb
# 02_your_first_readable_model.ipynb
#
# ./FlyRankAI01/outputs:
# charts	model_report.md  refresh_queue_sample.csv
#
# ./FlyRankAI01/outputs/charts:
# action_mix.svg	    top_feature_importance.svg	trend_distribution.svg
# confidence_mix.svg  top_reason_codes.svg
#
# ./FlyRankAI01/scripts:
# 01_prepare_features.py	04_evaluate_and_export.py  run_all.py
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project will provide recommendations based on historical data and learned patterns. The model cannot guarantee future ranking improvements because search engine rankings are influenced by many external factors. The recommendations should be treated as decision support rather than absolute predictions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
